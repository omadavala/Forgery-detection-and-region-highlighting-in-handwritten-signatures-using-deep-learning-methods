# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Dataset Paths
dataset_paths = {
    'CEDAR': r"D:\signature\CEDAR_relocated",
    'ICDAR': r"D:\signature\ICDAR-2011_relocated",
    'OTHER': r"D:\signature\Dataset_signature_final" 
}

# Load Images Function
def load_images(dataset_path):
    images = []
    labels = []
    for folder in os.listdir(dataset_path):
        folder_path = os.path.join(dataset_path, folder)
        if os.path.isdir(folder_path):
            for label, subfolder in enumerate(['original', 'forged']):
                subfolder_path = os.path.join(folder_path, subfolder)
                if os.path.exists(subfolder_path):
                    for file in os.listdir(subfolder_path):
                        img_path = os.path.join(subfolder_path, file)
                        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                        if img is not None:
                            img = cv2.resize(img, (128, 128))
                            images.append(img)
                            labels.append(label)
    return np.array(images), np.array(labels)

# Load All Datasets
all_images = []
all_labels = []

for dataset_name, dataset_path in dataset_paths.items():
    images, labels = load_images(dataset_path)
    all_images.append(images)
    all_labels.append(labels)

all_images = np.concatenate(all_images, axis=0)
all_labels = np.concatenate(all_labels, axis=0)

# Normalize Images
all_images = all_images / 255.0
all_images = all_images.reshape(-1, 128, 128, 1)

# Split Dataset
X_train, X_test, y_train, y_test = train_test_split(all_images, all_labels, test_size=0.2, random_state=42)

# PeleeNet Implementation
def stem_block(inputs):
    x = layers.Conv2D(32, (3, 3), strides=2, padding='same', activation='relu')(inputs)
    x = layers.Conv2D(32, (3, 3), padding='same', activation='relu')(x)
    x = layers.Conv2D(32, (3, 3), padding='same', activation='relu')(x)
    return x

def dense_block(x, filters, growth_rate, num_layers):
    for _ in range(num_layers):
        conv = layers.Conv2D(growth_rate, (3, 3), padding='same', activation='relu')(x)
        x = layers.Concatenate()([x, conv])
    return x

def feature_fusion(x, filters):
    x = layers.Conv2D(filters, (1, 1), padding='same', activation='relu')(x)
    return x

def build_peleenet():
    inputs = layers.Input(shape=(128, 128, 1))
    x = stem_block(inputs)
    x = dense_block(x, 32, 16, 3)
    x = feature_fusion(x, 128)
    x = layers.MaxPooling2D((2, 2))(x)
    x = dense_block(x, 64, 16, 3)
    x = feature_fusion(x, 256)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(128, activation='relu')(x)
    outputs = layers.Dense(1, activation='sigmoid')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

model = build_peleenet()
model.summary()

# Train Model
history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.2)

# Evaluate Model
y_pred = (model.predict(X_test) > 0.5).astype(int)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))

# Confusion Matrix Visualization
cm = confusion_matrix(y_test, y_pred)
cmd = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Genuine', 'Forged'])
cmd.plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.show()

# ROC Curve
fpr, tpr, _ = roc_curve(y_test, model.predict(X_test))
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='blue', label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

# Save Model
model.save('signature_forgery_peleenet.h5')
print("Model saved successfully.")
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)    │ (None, 128, 128, 1)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_95 (Conv2D)            │ (None, 64, 64, 32)        │             320 │ input_layer_6[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_96 (Conv2D)            │ (None, 64, 64, 32)        │           9,248 │ conv2d_95[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_97 (Conv2D)            │ (None, 64, 64, 32)        │           9,248 │ conv2d_96[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_98 (Conv2D)            │ (None, 64, 64, 16)        │           4,624 │ conv2d_97[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_43 (Concatenate)  │ (None, 64, 64, 48)        │               0 │ conv2d_97[0][0],           │
# │                               │                           │                 │ conv2d_98[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_99 (Conv2D)            │ (None, 64, 64, 16)        │           6,928 │ concatenate_43[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_44 (Concatenate)  │ (None, 64, 64, 64)        │               0 │ concatenate_43[0][0],      │
# │                               │                           │                 │ conv2d_99[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_100 (Conv2D)           │ (None, 64, 64, 16)        │           9,232 │ concatenate_44[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_45 (Concatenate)  │ (None, 64, 64, 80)        │               0 │ concatenate_44[0][0],      │
# │                               │                           │                 │ conv2d_100[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_101 (Conv2D)           │ (None, 64, 64, 128)       │          10,368 │ concatenate_45[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_4               │ (None, 32, 32, 128)       │               0 │ conv2d_101[0][0]           │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_102 (Conv2D)           │ (None, 32, 32, 16)        │          18,448 │ max_pooling2d_4[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_46 (Concatenate)  │ (None, 32, 32, 144)       │               0 │ max_pooling2d_4[0][0],     │
# │                               │                           │                 │ conv2d_102[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_103 (Conv2D)           │ (None, 32, 32, 16)        │          20,752 │ concatenate_46[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_47 (Concatenate)  │ (None, 32, 32, 160)       │               0 │ concatenate_46[0][0],      │
# │                               │                           │                 │ conv2d_103[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_104 (Conv2D)           │ (None, 32, 32, 16)        │          23,056 │ concatenate_47[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_48 (Concatenate)  │ (None, 32, 32, 176)       │               0 │ concatenate_47[0][0],      │
# │                               │                           │                 │ conv2d_104[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_105 (Conv2D)           │ (None, 32, 32, 256)       │          45,312 │ concatenate_48[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_5               │ (None, 16, 16, 256)       │               0 │ conv2d_105[0][0]           │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_average_pooling2d_5    │ (None, 256)               │               0 │ max_pooling2d_5[0][0]      │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_10 (Dense)              │ (None, 128)               │          32,896 │ global_average_pooling2d_… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_11 (Dense)              │ (None, 1)                 │             129 │ dense_10[0][0]             │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 190,561 (744.38 KB)
#  Trainable params: 190,561 (744.38 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 35s 313ms/step - accuracy: 0.5008 - loss: 0.6943 - val_accuracy: 0.5159 - val_loss: 0.6927
# Epoch 2/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 33s 335ms/step - accuracy: 0.5186 - loss: 0.6949 - val_accuracy: 0.6849 - val_loss: 0.6635
# Epoch 3/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 36s 362ms/step - accuracy: 0.6349 - loss: 0.6658 - val_accuracy: 0.6976 - val_loss: 0.6232
# Epoch 4/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 37s 377ms/step - accuracy: 0.6518 - loss: 0.6583 - val_accuracy: 0.6417 - val_loss: 0.6304
# Epoch 5/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 34s 339ms/step - accuracy: 0.6922 - loss: 0.5888 - val_accuracy: 0.6633 - val_loss: 0.6074
# Epoch 6/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 33s 329ms/step - accuracy: 0.7195 - loss: 0.5708 - val_accuracy: 0.6226 - val_loss: 0.7784
# Epoch 7/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 33s 332ms/step - accuracy: 0.7342 - loss: 0.5468 - val_accuracy: 0.7903 - val_loss: 0.4699
# Epoch 8/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 33s 331ms/step - accuracy: 0.7881 - loss: 0.4805 - val_accuracy: 0.7980 - val_loss: 0.4523
# Epoch 9/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 32s 327ms/step - accuracy: 0.8279 - loss: 0.4092 - val_accuracy: 0.8094 - val_loss: 0.4269
# Epoch 10/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 33s 330ms/step - accuracy: 0.8341 - loss: 0.3834 - val_accuracy: 0.8221 - val_loss: 0.4027
# Epoch 11/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 32s 326ms/step - accuracy: 0.8291 - loss: 0.3856 - val_accuracy: 0.8551 - val_loss: 0.3715
# Epoch 12/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 33s 329ms/step - accuracy: 0.8649 - loss: 0.3368 - val_accuracy: 0.8361 - val_loss: 0.3977
# Epoch 13/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 33s 337ms/step - accuracy: 0.8253 - loss: 0.3847 - val_accuracy: 0.8653 - val_loss: 0.3424
# Epoch 14/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 33s 332ms/step - accuracy: 0.8897 - loss: 0.2763 - val_accuracy: 0.8615 - val_loss: 0.3283
# Epoch 15/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 32s 321ms/step - accuracy: 0.8873 - loss: 0.2785 - val_accuracy: 0.8780 - val_loss: 0.3077
# Epoch 16/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 32s 321ms/step - accuracy: 0.8926 - loss: 0.2624 - val_accuracy: 0.8297 - val_loss: 0.3822
# Epoch 17/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 32s 328ms/step - accuracy: 0.8757 - loss: 0.2989 - val_accuracy: 0.8666 - val_loss: 0.3327
# Epoch 18/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 33s 330ms/step - accuracy: 0.9053 - loss: 0.2530 - val_accuracy: 0.7954 - val_loss: 0.4433
# Epoch 19/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 34s 344ms/step - accuracy: 0.9034 - loss: 0.2455 - val_accuracy: 0.8564 - val_loss: 0.3473
# Epoch 20/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 33s 331ms/step - accuracy: 0.8886 - loss: 0.2701 - val_accuracy: 0.8590 - val_loss: 0.3379
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step
# [[408  80]
#  [ 32 464]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.84      0.88       488
#            1       0.85      0.94      0.89       496
#
#     accuracy                           0.89       984
#    macro avg       0.89      0.89      0.89       984
# weighted avg       0.89      0.89      0.89       984
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully.

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Dataset Paths
dataset_paths = {
    'CEDAR': r"D:\signature\CEDAR_relocated",
    'ICDAR': r"D:\signature\ICDAR-2011_relocated",
    'OTHER': r"D:\signature\Dataset_signature_final" 
}

# Load Images Function
def load_images(dataset_path):
    images = []
    labels = []
    for folder in os.listdir(dataset_path):
        folder_path = os.path.join(dataset_path, folder)
        if os.path.isdir(folder_path):
            for label, subfolder in enumerate(['original', 'forged']):
                subfolder_path = os.path.join(folder_path, subfolder)
                if os.path.exists(subfolder_path):
                    for file in os.listdir(subfolder_path):
                        img_path = os.path.join(subfolder_path, file)
                        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                        if img is not None:
                            img = cv2.resize(img, (128, 128))
                            images.append(img)
                            labels.append(label)
    return np.array(images), np.array(labels)

# Load All Datasets
all_images = []
all_labels = []

for dataset_name, dataset_path in dataset_paths.items():
    images, labels = load_images(dataset_path)
    all_images.append(images)
    all_labels.append(labels)

all_images = np.concatenate(all_images, axis=0)
all_labels = np.concatenate(all_labels, axis=0)

# Normalize Images
all_images = all_images / 255.0
all_images = all_images.reshape(-1, 128, 128, 1)

# Split Dataset
X_train, X_test, y_train, y_test = train_test_split(all_images, all_labels, test_size=0.2, random_state=42)

# PeleeNet Implementation
def stem_block(inputs):
    x = layers.Conv2D(32, (3, 3), strides=2, padding='same', activation='relu')(inputs)
    x = layers.Conv2D(32, (3, 3), padding='same', activation='relu')(x)
    x = layers.Conv2D(32, (3, 3), padding='same', activation='relu')(x)
    return x

def dense_block(x, filters, growth_rate, num_layers):
    for _ in range(num_layers):
        conv = layers.Conv2D(growth_rate, (3, 3), padding='same', activation='relu')(x)
        x = layers.Concatenate()([x, conv])
    return x

def feature_fusion(x, filters):
    x = layers.Conv2D(filters, (1, 1), padding='same', activation='relu')(x)
    return x

def build_peleenet():
    inputs = layers.Input(shape=(128, 128, 1))
    x = stem_block(inputs)
    x = dense_block(x, 32, 16, 3)
    x = feature_fusion(x, 128)
    x = layers.MaxPooling2D((2, 2))(x)
    x = dense_block(x, 64, 16, 3)
    x = feature_fusion(x, 256)
    x = layers.MaxPooling2D((2, 2))(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(128, activation='relu')(x)
    outputs = layers.Dense(1, activation='sigmoid')(x)
    model = models.Model(inputs, outputs)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

model = build_peleenet()
model.summary()

# Train Model
history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.2)

# Evaluate Model
y_pred = (model.predict(X_test) > 0.5).astype(int)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))

# Confusion Matrix Visualization
cm = confusion_matrix(y_test, y_pred)
cmd = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Genuine', 'Forged'])
cmd.plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.show()

# ROC Curve
fpr, tpr, _ = roc_curve(y_test, model.predict(X_test))
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='blue', label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

# Save Model
model.save('signature_forgery_peleenet_cedar_icdar_other.h5')
print("Model saved successfully.")
# Out:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_7 (InputLayer)    │ (None, 128, 128, 1)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_106 (Conv2D)           │ (None, 64, 64, 32)        │             320 │ input_layer_7[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_107 (Conv2D)           │ (None, 64, 64, 32)        │           9,248 │ conv2d_106[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_108 (Conv2D)           │ (None, 64, 64, 32)        │           9,248 │ conv2d_107[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_109 (Conv2D)           │ (None, 64, 64, 16)        │           4,624 │ conv2d_108[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_49 (Concatenate)  │ (None, 64, 64, 48)        │               0 │ conv2d_108[0][0],          │
# │                               │                           │                 │ conv2d_109[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_110 (Conv2D)           │ (None, 64, 64, 16)        │           6,928 │ concatenate_49[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_50 (Concatenate)  │ (None, 64, 64, 64)        │               0 │ concatenate_49[0][0],      │
# │                               │                           │                 │ conv2d_110[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_111 (Conv2D)           │ (None, 64, 64, 16)        │           9,232 │ concatenate_50[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_51 (Concatenate)  │ (None, 64, 64, 80)        │               0 │ concatenate_50[0][0],      │
# │                               │                           │                 │ conv2d_111[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_112 (Conv2D)           │ (None, 64, 64, 128)       │          10,368 │ concatenate_51[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_6               │ (None, 32, 32, 128)       │               0 │ conv2d_112[0][0]           │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_113 (Conv2D)           │ (None, 32, 32, 16)        │          18,448 │ max_pooling2d_6[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_52 (Concatenate)  │ (None, 32, 32, 144)       │               0 │ max_pooling2d_6[0][0],     │
# │                               │                           │                 │ conv2d_113[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_114 (Conv2D)           │ (None, 32, 32, 16)        │          20,752 │ concatenate_52[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_53 (Concatenate)  │ (None, 32, 32, 160)       │               0 │ concatenate_52[0][0],      │
# │                               │                           │                 │ conv2d_114[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_115 (Conv2D)           │ (None, 32, 32, 16)        │          23,056 │ concatenate_53[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_54 (Concatenate)  │ (None, 32, 32, 176)       │               0 │ concatenate_53[0][0],      │
# │                               │                           │                 │ conv2d_115[0][0]           │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_116 (Conv2D)           │ (None, 32, 32, 256)       │          45,312 │ concatenate_54[0][0]       │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_7               │ (None, 16, 16, 256)       │               0 │ conv2d_116[0][0]           │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_average_pooling2d_6    │ (None, 256)               │               0 │ max_pooling2d_7[0][0]      │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_12 (Dense)              │ (None, 128)               │          32,896 │ global_average_pooling2d_… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_13 (Dense)              │ (None, 1)                 │             129 │ dense_12[0][0]             │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 190,561 (744.38 KB)
#  Trainable params: 190,561 (744.38 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 38s 325ms/step - accuracy: 0.4880 - loss: 0.6943 - val_accuracy: 0.6696 - val_loss: 0.6799
# Epoch 2/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 35s 353ms/step - accuracy: 0.5740 - loss: 0.6814 - val_accuracy: 0.6379 - val_loss: 0.6451
# Epoch 3/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 33s 328ms/step - accuracy: 0.6407 - loss: 0.6470 - val_accuracy: 0.7103 - val_loss: 0.6036
# Epoch 4/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 32s 320ms/step - accuracy: 0.6783 - loss: 0.6107 - val_accuracy: 0.6823 - val_loss: 0.5977
# Epoch 5/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 32s 321ms/step - accuracy: 0.7294 - loss: 0.5731 - val_accuracy: 0.7179 - val_loss: 0.5576
# Epoch 6/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 33s 331ms/step - accuracy: 0.7108 - loss: 0.5811 - val_accuracy: 0.7052 - val_loss: 0.5679
# Epoch 7/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 32s 325ms/step - accuracy: 0.7299 - loss: 0.5464 - val_accuracy: 0.7294 - val_loss: 0.5544
# Epoch 8/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 32s 323ms/step - accuracy: 0.7471 - loss: 0.5408 - val_accuracy: 0.7357 - val_loss: 0.5354
# Epoch 9/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 32s 326ms/step - accuracy: 0.7441 - loss: 0.5336 - val_accuracy: 0.6938 - val_loss: 0.5937
# Epoch 10/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 28s 281ms/step - accuracy: 0.7350 - loss: 0.5503 - val_accuracy: 0.7128 - val_loss: 0.5815
# Epoch 11/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 25s 255ms/step - accuracy: 0.7629 - loss: 0.5158 - val_accuracy: 0.6404 - val_loss: 0.6181
# Epoch 12/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 25s 255ms/step - accuracy: 0.7492 - loss: 0.5189 - val_accuracy: 0.7827 - val_loss: 0.4653
# Epoch 13/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 25s 256ms/step - accuracy: 0.7955 - loss: 0.4631 - val_accuracy: 0.8132 - val_loss: 0.4208
# Epoch 14/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 26s 260ms/step - accuracy: 0.8109 - loss: 0.4271 - val_accuracy: 0.8094 - val_loss: 0.4166
# Epoch 15/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 25s 257ms/step - accuracy: 0.8319 - loss: 0.4063 - val_accuracy: 0.8412 - val_loss: 0.3842
# Epoch 16/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 26s 259ms/step - accuracy: 0.8538 - loss: 0.3534 - val_accuracy: 0.8882 - val_loss: 0.3124
# Epoch 17/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 26s 260ms/step - accuracy: 0.8181 - loss: 0.4072 - val_accuracy: 0.8183 - val_loss: 0.3806
# Epoch 18/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 26s 258ms/step - accuracy: 0.8884 - loss: 0.2988 - val_accuracy: 0.8818 - val_loss: 0.3076
# Epoch 19/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 26s 259ms/step - accuracy: 0.8904 - loss: 0.2949 - val_accuracy: 0.9123 - val_loss: 0.2734
# Epoch 20/20
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 26s 258ms/step - accuracy: 0.8824 - loss: 0.3016 - val_accuracy: 0.9072 - val_loss: 0.2853
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step
# [[449  39]
#  [ 61 435]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90       488
#            1       0.92      0.88      0.90       496
#
#     accuracy                           0.90       984
#    macro avg       0.90      0.90      0.90       984
# weighted avg       0.90      0.90      0.90       984
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully.
